# %% [markdown]
# # 01 – Data Ingestion
#
# This notebook is responsible for loading the raw datasets used in the credit risk pipeline.
#
# Responsibilities:
# - Load raw training and testing data
# - Perform basic sanity checks
# - No transformations or feature engineering are applied here

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from pathlib import Path

sys.path.append("..")

from src.data_ingestion import DataIngestion

# %%
ingestion = DataIngestion()
df_training, df_testing = ingestion.load_files()

# %%
df_training.shape, df_testing.shape
# Out:
# ((440833, 12), (64374, 12))

# %%
processed_dir = Path("../data/processed")
processed_dir.mkdir(parents=True, exist_ok=True)

# %%
df_training.to_parquet("../data/processed/train_raw.parquet", index=False)
df_testing.to_parquet("../data/processed/test_raw.parquet", index=False)

# %%
df_training
# Out:
#         CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0              2.0  30.0  Female    39.0             14.0            5.0
# 1              3.0  65.0  Female    49.0              1.0           10.0
# 2              4.0  55.0  Female    14.0              4.0            6.0
# 3              5.0  58.0    Male    38.0             21.0            7.0
# 4              6.0  23.0    Male    32.0             20.0            5.0
# ...            ...   ...     ...     ...              ...            ...
# 440828    449995.0  42.0    Male    54.0             15.0            1.0
# 440829    449996.0  25.0  Female     8.0             13.0            1.0
# 440830    449997.0  26.0    Male    35.0             27.0            1.0
# 440831    449998.0  28.0    Male    55.0             14.0            2.0
# 440832    449999.0  31.0    Male    48.0             20.0            1.0
#
#         Payment Delay Subscription Type Contract Length  Total Spend  \
# ...
