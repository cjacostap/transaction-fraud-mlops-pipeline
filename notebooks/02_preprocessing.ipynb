# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from pathlib import Path

sys.path.append("..")

from src.preprocessing import PreProcessing

# %%
preprocessing = PreProcessing()
df_training_final, df_testing_final = preprocessing.cleaning()
